# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib

# %% [markdown]
# - простые графики

# %%
# имитация данных
# массив (вектор-строка) из 1000 значений
# линейной последовательности от 0 до 10
x = np.linspace(0, 10, 1000)
# x

# %%
# данные для оси y
y = np.sin(x)

# %%
# рисуем график
plt.plot(x, y)
plt.show()

# %%
# совмещение двух графиков в одном окне
plt.plot(x, y)
plt.plot(x, np.cos(x))
plt.show()

# %%
# интерактивный режим
# %matplotlib notebook

# метки и легенды графиков

# легенды
plt.plot(x, y, label='sin')
plt.plot(x, np.cos(x), label='cos')

plt.legend()

# заголовок
plt.title("Синус и косинус от x")
# метки
plt.xlabel("x")
plt.ylabel("sin(x) & cos(x)")


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# цвет и вид линий

# цвета можно задавать разными способами
plt.plot(x, np.sin(x), color='blue') # по названию
plt.plot(x, np.sin(x + 1), color='g') # по перечень букв цветов (rgbcmyk)
plt.plot(x, np.sin(x + 2), color='0.75') # оттенки серого в диапазоне от 0 до 1
plt.plot(x, np.sin(x + 3), color=(1.0, 0.5, 0.2)) # RGB-кортеж, значения от 0 до 1
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# вид линий
plt.plot(x, x + 3, linestyle='--') # штриховая линия
plt.plot(x, x + 2, linestyle=':') # пунктирная линия
plt.plot(x, x + 1, linestyle='-.') # штрих-пунктирная линия
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# объединение кодов вида и цвета линий
plt.plot(x, x + 3, '--g') # штриховая зеленая линия
plt.plot(x, x + 2, ':k') # пунктирная черная линия
plt.plot(x, x + 1, '-.r') # штрих-пунктирная линия
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# - гистограммы

# %%
# имитация данных
# случайные данные из нормального (гауссова) распределения
data = np.random.randn(1000)

# рисуем гистограмму
plt.hist(data, bins=100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# - Пример с президентами США

# %%
data = pd.read_csv('president_heights.csv')
data.head()
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163
# 4      5       James Monroe         183

# %%
data.loc[:, 'height(cm)'].mean()
# Out:
# 179.73809523809524

# %%
data.loc[:, 'height(cm)'].min()
# Out:
# 163

# %%
min_height = data.loc[:, 'height(cm)'].min()
data.loc[data['height(cm)'] == min_height, 'name']
# Out:
# 3    James Madison
# Name: name, dtype: object

# %%
max_height = data.loc[:, 'height(cm)'].max()
data.loc[data['height(cm)'] == max_height, 'name']
# Out:
# 15      Abraham Lincoln
# 33    Lyndon B. Johnson
# Name: name, dtype: object

# %%
max_height
# Out:
# 193

# %%
heights = data.loc[:, 'height(cm)']

plt.hist(heights)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# - простые диаграммы рассеивания

# %%
# имитационные данные
x = np.random.randn(50)
y = np.random.randn(50)

colors = np.random.randn(50)
sizes = np.random.randn(50) * 100

# диаграмма рассеивания
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5)
plt.colorbar(label="colors")

plt.show()

# %% [markdown]
# - Пример с городами Якутии

# %%
# загрузка Excel-таблицы
cities = pd.read_excel('cities_of_Yakutia.xlsx')
cities
# Out:
#             город  население  площадь  широта  долгота
# 0          Якутск     318768      122      62      129
# 1        Нерюнгри      57009       99      56      124
# 2         Вилюйск      11095       15      63      121
# 3           Ленск      23479       49      60      114
# 4           Алдан      20595       33      58      125
# 5       Олёкминск       9213       12      60      120
# 6   Среднеколымск       3489       20      67      153
# 7        Покровск       9256       11      61      129
# 8          Мирный      35223       15      62      113
# 9           Нюрба       9786       19      63      118
# 10         Томмот       6935       26      58      126
# 11        Удачный      11676        2      66      112
# 12      Верхоянск       1122       25      67      133

# %%
# извлечение данных
pop = cities['население']
area = cities['площадь']

lat = cities['широта']
lon = cities['долгота']

# lon

# %%
# визуализация

pop_log = np.log10(pop)

plt.scatter(lon, lat, c=pop_log, s=area)
plt.colorbar(label="log10(население)")

plt.title('Города Якутии')
plt.xlabel('долгота')
plt.ylabel('широта')

plt.show()
