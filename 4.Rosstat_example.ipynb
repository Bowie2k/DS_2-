# %% [markdown]
# # Анализ данных из Росстат

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# загрузка данных
stat_data = pd.read_excel('https://rosstat.gov.ru/storage/mediabank/cen-god.xls', skiprows=2, decimal=',').dropna()
stat_data.head(10)
# Out:
#                                           ПОКАЗАТЕЛИ    1991    1992     1993  \
# 1                   Говядина (кроме бескостного мяса)  15.54   221.5  2201.27
# 2                    Свинина (кроме бескостного мяса)  14.38     260  2672.81
# 3                      Куры охлажденные и мороженые1)  13.57  194.76  2238.98
# 4                                   Колбаса вареная2)     17     271   3351.3
# 5                            Консервы мясные3), 350 г   8.87   163.9  1165.48
# 6                      Рыба мороженая неразделанная4)   2.32   129.5  1088.73
# 7               Рыба соленая, маринованная, копченая    5.72   272.6  2598.96
# 8   Консервы рыбные натуральные и с добавлением ма...   3.91     120  1040.71
# 9                                 Масло сливочное 5)   12.24     413  2912.58
# 10                             Масло подсолнечное 6)    5.48     190   1364.9
#
#         1994     1995     1996     1997   1998   1999  ...    2010    2011  \
# ...

# %%
stat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 1 to 86
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    ПОКАЗАТЕЛИ   78 non-null     object
#  1   1991          78 non-null     object
#  2   1992          78 non-null     object
#  3   1993          78 non-null     object
#  4   1994          78 non-null     float64
#  5   1995          78 non-null     float64
#  6   1996          78 non-null     float64
#  7   1997          78 non-null     float64
#  8   1998          78 non-null     float64
#  9   1999          78 non-null     float64
#  10  2000          78 non-null     float64
#  11  2001          78 non-null     float64
#  12  2002          78 non-null     float64
#  13  2003          78 non-null     float64
#  14  2004          78 non-null     float64
#  15  2005          78 non-null     float64
#  16  2006          78 non-null     float64
# ...

# %%
stat_data.columns
# Out:
# Index([' ПОКАЗАТЕЛИ ',           1991,           1992,           1993,
#                  1994,           1995,           1996,           1997,
#                  1998,           1999,           2000,           2001,
#                  2002,           2003,           2004,           2005,
#                  2006,           2007,           2008,           2009,
#                  2010,           2011,           2012,           2013,
#                  2014,           2015,           2016,           2017,
#                  2018,           2019],
#       dtype='object')

# %%
# приведение значений ключей столбцов в единый строковой тип
stat_data.columns = stat_data.columns.astype('str')
stat_data.columns
# Out:
# Index([' ПОКАЗАТЕЛИ ', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
# транспонирование таблицы
stat_data = stat_data.T
stat_data.head()
# Out:
#                                              1   \
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)
# 1991                                      15.54
# 1992                                      221.5
# 1993                                    2201.27
# 1994                                    5186.28
#
#                                             2   \
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)
# 1991                                     14.38
# 1992                                       260
# 1993                                   2672.81
# 1994                                   6579.38
#
#                                           3                  4   \
#  ПОКАЗАТЕЛИ   Куры охлажденные и мороженые1)  Колбаса вареная2)
# 1991                                   13.57                 17
# 1992                                  194.76                271
# 1993                                 2238.98             3351.3
# ...

# %%
# в качестве ключей столбцов устанавливаем значения категорий
stat_data.columns = stat_data.loc[' ПОКАЗАТЕЛИ ', :]
stat_data.head()
# Out:
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)
# 1991                                      15.54
# 1992                                      221.5
# 1993                                    2201.27
# 1994                                    5186.28
#
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)
# 1991                                     14.38
# 1992                                       260
# 1993                                   2672.81
# 1994                                   6579.38
#
#  ПОКАЗАТЕЛИ   Куры охлажденные и мороженые1)  Колбаса вареная2)  \
#  ПОКАЗАТЕЛИ   Куры охлажденные и мороженые1)  Колбаса вареная2)
# 1991                                   13.57                 17
# 1992                                  194.76                271
# 1993                                 2238.98             3351.3
# ...

# %%
stat_data.iloc[:, :10]
# Out:
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)
# 1991                                      15.54
# 1992                                      221.5
# 1993                                    2201.27
# 1994                                    5186.28
# 1995                                      12547
# 1996                                      14137
# 1997                                      15787
# 1998                                      30.04
# 1999                                      42.01
# 2000                                      52.72
# 2001                                      70.33
# 2002                                      72.56
# 2003                                       73.9
# 2004                                      93.41
# 2005                                     115.77
# 2006                                     131.67
# 2007                                     139.49
# ...

# %%
# срезаем из таблицы данные до 1998 года, т.к. там присутствуют аномальные значения
stat_data = stat_data.loc['1998':, :]
stat_data.head()
# Out:
#  ПОКАЗАТЕЛИ  Говядина (кроме бескостного мяса)  \
# 1998                                     30.04
# 1999                                     42.01
# 2000                                     52.72
# 2001                                     70.33
# 2002                                     72.56
#
#  ПОКАЗАТЕЛИ  Свинина (кроме бескостного мяса) Куры охлажденные и мороженые1)  \
# 1998                                    33.99                          30.74
# 1999                                    43.37                          39.28
# 2000                                    58.45                           48.8
# 2001                                    79.22                          56.92
# 2002                                    80.98                          58.38
#
#  ПОКАЗАТЕЛИ  Колбаса вареная2) Консервы мясные3), 350 г  \
# 1998                     43.81                     15.5
# 1999                     61.56                    18.16
# ...

# %%
stat_data.iloc[:, 60:]
# Out:
#  ПОКАЗАТЕЛИ  Проезд в троллейбусе, за поездку Проезд в метро, за поездку  \
# 1998                                     1.37                        2.2
# 1999                                     1.82                       3.08
# 2000                                     2.58                       4.31
# 2001                                     3.16                       4.56
# 2002                                     4.27                       6.09
# 2003                                     4.63                       6.13
# 2004                                     5.42                       7.97
# 2005                                      6.2                      10.33
# 2006                                     7.24                      11.57
# 2007                                     8.23                      13.05
# 2008                                     9.66                      14.82
# 2009                                    10.97                      17.43
# ...

# %%
# символ "-" заменяем на 0
stat_data = stat_data.replace('-', 0.0)
stat_data.iloc[:, 60:]
# Out:
#  ПОКАЗАТЕЛИ  Проезд в троллейбусе, за поездку Проезд в метро, за поездку  \
# 1998                                     1.37                        2.2
# 1999                                     1.82                       3.08
# 2000                                     2.58                       4.31
# 2001                                     3.16                       4.56
# 2002                                     4.27                       6.09
# 2003                                     4.63                       6.13
# 2004                                     5.42                       7.97
# 2005                                      6.2                      10.33
# 2006                                     7.24                      11.57
# 2007                                     8.23                      13.05
# 2008                                     9.66                      14.82
# 2009                                    10.97                      17.43
# ...

# %%
# проверка значений
stat_data.values
# Out:
# array([[30.04, 33.99, 30.74, ..., 135.41, 41.9, 24.4],
#        [42.01, 43.37, 39.28, ..., 197.9, 52.67, 31.22],
#        [52.72, 58.45, 48.8, ..., 279.76, 62.97, 37.99],
#        ...,
#        [320.34, 255.87, 126.29, ..., 1869.65, 683.9, 370.24],
#        [330.58, 275.26, 151.27, ..., 1869.54, 724.61, 382.06],
#        ['350.05', '264.55', '143.13', ..., '1937.53', '780.86', '398.49']],
#       dtype=object)

# %%
# конвертирование строковых значений в числовой тип (float)
stat_data = stat_data.astype(np.float32)
stat_data.values
# Out:
# array([[  30.04,   33.99,   30.74, ...,  135.41,   41.9 ,   24.4 ],
#        [  42.01,   43.37,   39.28, ...,  197.9 ,   52.67,   31.22],
#        [  52.72,   58.45,   48.8 , ...,  279.76,   62.97,   37.99],
#        ...,
#        [ 320.34,  255.87,  126.29, ..., 1869.65,  683.9 ,  370.24],
#        [ 330.58,  275.26,  151.27, ..., 1869.54,  724.61,  382.06],
#        [ 350.05,  264.55,  143.13, ..., 1937.53,  780.86,  398.49]],
#       dtype=float32)

# %%
# проверка ключей столбцов
stat_data.columns
# Out:
# Index(['Говядина (кроме бескостного мяса)', 'Свинина (кроме бескостного мяса)',
#        'Куры охлажденные и мороженые1)', 'Колбаса вареная2)',
#        'Консервы мясные3), 350 г', 'Рыба мороженая неразделанная4)',
#        'Рыба соленая, маринованная, копченая ',
#        'Консервы рыбные натуральные и с добавлением масла,  350 г',
#        'Масло сливочное 5) ', 'Масло подсолнечное 6) ',
#        'Молоко питьевое цельное  пастеризованное 2,5-3,2% жирности7), за л',
#        'Сыры сычужные твердые и мягкие', 'Яйца куриные, за 10 шт.',
#        'Сахар-песок', 'Чай черный байховый', 'Мука пшеничная',
#        'Хлеб и булочные изделия из пшеничной муки высшего сорта',
#        'Рис шлифованный',
#        'Макаронные изделия из пшеничной муки высшего сорта8)', 'Картофель',
#        'Капуста белокочанная свежая', 'Лук репчатый', 'Яблоки',
#        'Водка крепостью 40% об.спирта и выше9), за л',
#        'Коньяк ординарный отечественный10), за  л',
# ...

# %%
# удаление лишних символов пробела (" ") из ключей столбцов
stat_data.columns = stat_data.columns.str.strip(" ")
stat_data.columns
# Out:
# Index(['Говядина (кроме бескостного мяса)', 'Свинина (кроме бескостного мяса)',
#        'Куры охлажденные и мороженые1)', 'Колбаса вареная2)',
#        'Консервы мясные3), 350 г', 'Рыба мороженая неразделанная4)',
#        'Рыба соленая, маринованная, копченая',
#        'Консервы рыбные натуральные и с добавлением масла,  350 г',
#        'Масло сливочное 5)', 'Масло подсолнечное 6)',
#        'Молоко питьевое цельное  пастеризованное 2,5-3,2% жирности7), за л',
#        'Сыры сычужные твердые и мягкие', 'Яйца куриные, за 10 шт.',
#        'Сахар-песок', 'Чай черный байховый', 'Мука пшеничная',
#        'Хлеб и булочные изделия из пшеничной муки высшего сорта',
#        'Рис шлифованный',
#        'Макаронные изделия из пшеничной муки высшего сорта8)', 'Картофель',
#        'Капуста белокочанная свежая', 'Лук репчатый', 'Яблоки',
#        'Водка крепостью 40% об.спирта и выше9), за л',
#        'Коньяк ординарный отечественный10), за  л',
# ...

# %%
# "очищенный" DataFrame можно сохранить в виде нового excel-файла
stat_data.to_excel('prices_stat_data_1998-2019.xlsx')

# %%
stat_data['Консервы мясные3), 350 г']
# Out:
# 1998     15.500000
# 1999     18.160000
# 2000     19.520000
# 2001     24.070000
# 2002     26.549999
# 2003     28.180000
# 2004     32.040001
# 2005     37.009998
# 2006     40.099998
# 2007     43.130001
# 2008     54.029999
# 2009     60.290001
# 2010     63.790001
# 2011     70.349998
# 2012     75.220001
# 2013     79.330002
# 2014     94.419998
# 2015    117.040001
# 2016    121.370003
# 2017    125.209999
# 2018    130.130005
# 2019    139.470001
# Name: Консервы мясные3), 350 г, dtype: float32

# %%
# в сколько раз изменилась сред. цена на опред. категорию
stat_data.loc['2019', 'Консервы мясные3), 350 г'] / stat_data.loc['1998', 'Консервы мясные3), 350 г']
# Out:
# 8.998065

# %%
stat_data.loc['2019', 'Электроэнергия в квартирах  без электроплит за минимальный объем потребления29), за 100 кВт·ч'] / stat_data.loc['1998', 'Электроэнергия в квартирах  без электроплит за минимальный объем потребления29), за 100 кВт·ч']
# Out:
# 23.44295

# %%
stat_data.loc['2019', 'Хлеб и булочные изделия из пшеничной муки высшего сорта'] / stat_data.loc['1998', 'Хлеб и булочные изделия из пшеничной муки высшего сорта']
# Out:
# 12.05919

# %%
# извлечение интересующих данных

prices_1 = stat_data['Консервы мясные3), 350 г']
prices_2 = stat_data['Хлеб и булочные изделия из пшеничной муки высшего сорта']
prices_3 = stat_data['Общий анализ крови33)']

# %%
# извлекаем года для временной шкалы, попутно (на лету) конвертируя в целочисленный тип
years = stat_data.index.astype(int)
years
# Out:
# Int64Index([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#             2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#            dtype='int64')

# %%
# визуализация

plt.plot(years, prices_1, label='Консервы')
plt.plot(years, prices_2, label='Хлеб')
plt.plot(years, prices_3, label='Анализ крови')

plt.legend()

plt.title('Динамика ср. цен с 1998 по 2019 гг')
plt.xlabel('годы')
plt.ylabel('ср. цены (руб)')

plt.show()
